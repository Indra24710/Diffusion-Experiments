# %%
import os
import pickle
import numpy as np

# %%
path = "./experiments/generation/2024-12-24_ldm-celebahq-256_expt-1_vanilla-image-generation/latents"
latent_files = os.listdir(path)
len(latent_files)
# Out:
# 1000

# %%
file = latent_files[0]
f = pickle.load(open(os.path.join(path, file), "rb"))
f.shape
# Out:
# (1, 3, 64, 64)

# %%
f
# Out:
# array([[[[-0.530559  , -1.1299706 , -0.6733835 , ...,  1.5432107 ,
#            0.12251054,  0.08378837],
#          [-0.72494143, -1.2368109 ,  0.3960015 , ...,  0.5797944 ,
#           -0.3581023 ,  0.84404135],
#          [ 0.52877504, -0.35116622, -0.8124409 , ...,  1.9557005 ,
#           -1.7315356 , -0.15193252],
#          ...,
#          [ 2.5589223 , -1.4092287 ,  1.1298653 , ...,  0.00718808,
#           -0.61405015,  0.628987  ],
#          [ 1.2103981 , -1.5683109 ,  1.0043396 , ...,  1.7323107 ,
#            0.9495029 ,  2.1151307 ],
#          [ 1.1022851 ,  1.3242298 , -0.5761259 , ..., -1.233948  ,
#           -0.38839588,  0.36948475]],
#
#         [[-0.6002227 ,  0.8373392 ,  0.5101028 , ...,  1.6718878 ,
#            0.3082544 , -0.1031648 ],
#          [-1.0357748 ,  0.4862002 ,  1.8001162 , ...,  0.65344536,
#            0.84940946,  0.80645335],
#          [ 1.5576377 ,  0.7654724 , -0.58157057, ...,  0.7272177 ,
#           -0.19743648, -2.1922162 ],
# ...
